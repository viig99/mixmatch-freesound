# %%
import pandas as pd
import os
import numpy as np

sub_v1 = pd.read_csv('/Users/vigi99/AirtelDEV/MixMatch-pytorch/submission/submission_v1.csv', index_col='fname')
sub_v2 = pd.read_csv('/Users/vigi99/AirtelDEV/MixMatch-pytorch/submission/submission_v2.csv', index_col='fname')
sub_v3 = pd.read_csv('/Users/vigi99/AirtelDEV/MixMatch-pytorch/submission/submission_v3.csv', index_col='fname')
test_path = os.path.abspath('/Users/vigi99/kaggle/freesound/data/test')

def labels_values(df, audio_file, name):
    predicted_labels = df[df.index == audio_file]
    top_5 = np.argsort(predicted_labels.values[0])[-5:].tolist()
    top_5.reverse()
    print("===============")
    print(name)
    print(np.array(predicted_labels.columns)[top_5])
    print(np.array(predicted_labels.values)[0][top_5])
    print("===============")
    print()

# %%
random_audio_file = np.random.choice(sub_v1.index.values)
random_audio_file_path = os.path.join(test_path, random_audio_file)
print(random_audio_file_path)
import IPython.display as ipd
labels_values(sub_v1, random_audio_file, 'V1')
labels_values(sub_v2, random_audio_file, 'V2')
labels_values(sub_v3, random_audio_file, 'V3')
ipd.Audio(random_audio_file_path)
# Out:
# /Users/vigi99/kaggle/freesound/data/test/143e6d96.wav
# ===============
# V1
# ['Keys_jangling' 'Bicycle_bell' 'Computer_keyboard' 'Scissors'
#  'Cutlery_and_silverware']
# [0.7642408  0.32839835 0.22249009 0.20126814 0.19578716]
# ===============
#
# ===============
# V2
# ['Keys_jangling' 'Bicycle_bell' 'Computer_keyboard'
#  'Cutlery_and_silverware' 'Squeak']
# [0.59241194 0.38837385 0.28006685 0.15121193 0.0893864 ]
# ===============
#
# ===============
# V3
# ['Keys_jangling' 'Bicycle_bell' 'Cutlery_and_silverware' 'Printer'
#  'Computer_keyboard']
# [0.63888532 0.49594113 0.27364397 0.2024563  0.19069602]
# ===============
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = sub_v3.idxmax(axis=1)
from collections import Counter
Counter(x.values).most_common()
# Out:
# [('Computer_keyboard', 48),
#  ('Stream', 43),
#  ('Tick-tock', 38),
#  ('Drawer_open_or_close', 36),
#  ('Water_tap_and_faucet', 31),
#  ('Bicycle_bell', 27),
#  ('Bass_drum', 26),
#  ('Toilet_flush', 26),
#  ('Crackle', 25),
#  ('Knock', 25),
#  ('Microwave_oven', 25),
#  ('Race_car_and_auto_racing', 25),
#  ('Shatter', 23),
#  ('Cheering', 22),
#  ('Female_singing', 22),
#  ('Scissors', 22),
#  ('Burping_and_eructation', 22),
#  ('Zipper_(clothing)', 21),
#  ('Electric_guitar', 21),
#  ('Harmonica', 20),
#  ('Screaming', 20),
#  ('Cricket', 19),
#  ('Finger_snapping', 18),
#  ('Keys_jangling', 17),
#  ('Applause', 17),
#  ('Meow', 17),
#  ('Sneeze', 16),
#  ('Run', 16),
#  ('Church_bell', 16),
#  ('Sigh', 16),
#  ('Frying_(food)', 16),
#  ('Bass_guitar', 16),
#  ('Purr', 16),
#  ('Car_passing_by', 15),
#  ('Buzz', 14),
#  ('Hiss', 14),
#  ('Male_singing', 14),
#  ('Female_speech_and_woman_speaking', 13),
#  ('Chink_and_clink', 12),
#  ('Marimba_and_xylophone', 12),
#  ('Drip', 11),
#  ('Mechanical_fan', 11),
#  ('Bark', 11),
#  ('Waves_and_surf', 11),
#  ('Sink_(filling_or_washing)', 11),
#  ('Chewing_and_mastication', 11),
#  ('Cutlery_and_silverware', 10),
#  ('Gong', 10),
#  ('Printer', 10),
#  ('Whispering', 9),
#  ('Slam', 9),
#  ('Gurgling', 9),
#  ('Walk_and_footsteps', 9),
#  ('Skateboard', 9),
#  ('Yell', 9),
#  ('Acoustic_guitar', 8),
#  ('Traffic_noise_and_roadway_noise', 8),
#  ('Writing', 7),
#  ('Motorcycle', 7),
#  ('Bus', 7),
#  ('Fill_(with_liquid)', 7),
#  ('Male_speech_and_man_speaking', 6),
#  ('Chirp_and_tweet', 6),
#  ('Bathtub_(filling_or_washing)', 5),
#  ('Fart', 5),
#  ('Accordion', 5),
#  ('Cupboard_open_or_close', 5),
#  ('Clapping', 4),
#  ('Trickle_and_dribble', 4),
#  ('Glockenspiel', 4),
#  ('Child_speech_and_kid_speaking', 3),
#  ('Hi-hat', 3),
#  ('Crowd', 3),
#  ('Tap', 3),
#  ('Strum', 3),
#  ('Raindrop', 2),
#  ('Gasp', 2),
#  ('Squeak', 1)]

# %%
sub_dev = pd.read_csv('/Users/vigi99/AirtelDEV/MixMatch-pytorch/submission/submission_split_train_dev.csv', index_col='fname')
sub_test = pd.read_csv('/Users/vigi99/AirtelDEV/MixMatch-pytorch/submission/submission_split_train_test.csv', index_col='fname')

# %%
x = sub_dev.idxmax(axis=1)
from collections import Counter
Counter(x.values).most_common()
# Out:
# [('Car_passing_by', 12),
#  ('Crackle', 9),
#  ('Meow', 8),
#  ('Cricket', 8),
#  ('Child_speech_and_kid_speaking', 8),
#  ('Drawer_open_or_close', 7),
#  ('Stream', 7),
#  ('Male_singing', 6),
#  ('Sneeze', 6),
#  ('Clapping', 6),
#  ('Toilet_flush', 6),
#  ('Bicycle_bell', 5),
#  ('Writing', 5),
#  ('Microwave_oven', 5),
#  ('Slam', 5),
#  ('Fart', 5),
#  ('Sigh', 5),
#  ('Gurgling', 4),
#  ('Female_speech_and_woman_speaking', 4),
#  ('Acoustic_guitar', 4),
#  ('Marimba_and_xylophone', 4),
#  ('Screaming', 4),
#  ('Glockenspiel', 4),
#  ('Chewing_and_mastication', 4),
#  ('Purr', 4),
#  ('Buzz', 4),
#  ('Skateboard', 4),
#  ('Raindrop', 4),
#  ('Tick-tock', 4),
#  ('Cupboard_open_or_close', 3),
#  ('Gasp', 3),
#  ('Male_speech_and_man_speaking', 3),
#  ('Female_singing', 3),
#  ('Fill_(with_liquid)', 3),
#  ('Sink_(filling_or_washing)', 3),
#  ('Mechanical_fan', 3),
#  ('Gong', 3),
#  ('Zipper_(clothing)', 3),
#  ('Scissors', 3),
#  ('Finger_snapping', 3),
#  ('Hi-hat', 3),
#  ('Computer_keyboard', 2),
#  ('Burping_and_eructation', 2),
#  ('Bass_drum', 2),
#  ('Harmonica', 2),
#  ('Knock', 2),
#  ('Accelerating_and_revving_and_vroom', 2),
#  ('Bus', 2),
#  ('Electric_guitar', 2),
#  ('Race_car_and_auto_racing', 2),
#  ('Run', 2),
#  ('Bark', 2),
#  ('Chink_and_clink', 2),
#  ('Yell', 2),
#  ('Printer', 2),
#  ('Accordion', 2),
#  ('Bass_guitar', 2),
#  ('Chirp_and_tweet', 2),
#  ('Whispering', 2),
#  ('Water_tap_and_faucet', 1),
#  ('Drip', 1),
#  ('Cutlery_and_silverware', 1),
#  ('Church_bell', 1),
#  ('Motorcycle', 1),
#  ('Waves_and_surf', 1),
#  ('Hiss', 1),
#  ('Keys_jangling', 1),
#  ('Traffic_noise_and_roadway_noise', 1),
#  ('Trickle_and_dribble', 1),
#  ('Shatter', 1),
#  ('Walk_and_footsteps', 1),
#  ('Dishes_and_pots_and_pans', 1),
#  ('Tap', 1),
#  ('Frying_(food)', 1)]

# %%
x = sub_test.idxmax(axis=1)
from collections import Counter
Counter(x.values).most_common()
# Out:
# [('Crackle', 10),
#  ('Toilet_flush', 9),
#  ('Stream', 9),
#  ('Bicycle_bell', 8),
#  ('Cupboard_open_or_close', 7),
#  ('Race_car_and_auto_racing', 7),
#  ('Buzz', 6),
#  ('Car_passing_by', 6),
#  ('Tick-tock', 6),
#  ('Gurgling', 6),
#  ('Gong', 6),
#  ('Writing', 6),
#  ('Child_speech_and_kid_speaking', 5),
#  ('Bass_guitar', 5),
#  ('Clapping', 5),
#  ('Mechanical_fan', 5),
#  ('Knock', 5),
#  ('Whispering', 5),
#  ('Chink_and_clink', 4),
#  ('Cheering', 4),
#  ('Hi-hat', 4),
#  ('Water_tap_and_faucet', 4),
#  ('Sigh', 4),
#  ('Drawer_open_or_close', 4),
#  ('Keys_jangling', 4),
#  ('Waves_and_surf', 4),
#  ('Cricket', 4),
#  ('Female_singing', 4),
#  ('Male_singing', 4),
#  ('Electric_guitar', 4),
#  ('Church_bell', 3),
#  ('Burping_and_eructation', 3),
#  ('Bark', 3),
#  ('Frying_(food)', 3),
#  ('Microwave_oven', 3),
#  ('Scissors', 3),
#  ('Glockenspiel', 3),
#  ('Harmonica', 3),
#  ('Bus', 3),
#  ('Printer', 3),
#  ('Run', 3),
#  ('Yell', 3),
#  ('Bass_drum', 3),
#  ('Traffic_noise_and_roadway_noise', 3),
#  ('Fill_(with_liquid)', 2),
#  ('Screaming', 2),
#  ('Slam', 2),
#  ('Drip', 2),
#  ('Sneeze', 2),
#  ('Meow', 2),
#  ('Raindrop', 2),
#  ('Gasp', 2),
#  ('Female_speech_and_woman_speaking', 2),
#  ('Purr', 2),
#  ('Acoustic_guitar', 2),
#  ('Computer_keyboard', 2),
#  ('Finger_snapping', 2),
#  ('Male_speech_and_man_speaking', 2),
#  ('Motorcycle', 2),
#  ('Walk_and_footsteps', 2),
#  ('Applause', 1),
#  ('Chirp_and_tweet', 1),
#  ('Cutlery_and_silverware', 1),
#  ('Bathtub_(filling_or_washing)', 1),
#  ('Accordion', 1),
#  ('Strum', 1),
#  ('Hiss', 1),
#  ('Skateboard', 1),
#  ('Shatter', 1),
#  ('Squeak', 1),
#  ('Marimba_and_xylophone', 1)]
